# %% [markdown]
# <a href="https://colab.research.google.com/github/zapcloma-ops/CS1_zioncloma_7emerald_respository/blob/main/CS1_FA2_CLOMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Input your first number: "))
num2 = int(input("Input your second number: "))
num3 = int(input("Input your third number: "))

if num1 > num2 and num1 > num3:
  print("The largest number is: ", num1)
elif num2 > num1 and num2 > num3:
  print("The largest number is: ", num2)
else:
  print("The largest number is: ", num3)
# Out:
# Input your first number: 6
# Input your second number: 7
# Input your third number: 3
# The largest number is:  7
